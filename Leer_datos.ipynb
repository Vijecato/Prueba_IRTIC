# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
datos_csv = pd.read_csv("C:/Users/vijec/Desktop/TRBAJO_EXTRACURRICULAR/Intento_javi_webservice/Datos/sparql_2024-09-24_07-41-03Z.csv")

# %%
datos_csv.head()
# Out:
#      idP   nameP    nameType                                        uriAutor  \
# 0   1030  Nº 311       Silla  http://data.arxiuvalencia.eu/organization/3510
# 1  10649   Magic  Estantería  http://data.arxiuvalencia.eu/organization/3307
# 2  10649   Magic  Estantería  http://data.arxiuvalencia.eu/organization/3307
# 3  10649   Magic        Mesa  http://data.arxiuvalencia.eu/organization/3307
# 4  10649   Magic        Mesa  http://data.arxiuvalencia.eu/organization/3307
#
#                  nameAutor                                             uriMat  \
# 0  Vicente García Miralles  https://data.arxiuvalencia.eu/vocabulary/c_13b...
# 1         Punt Mobles S.L.  https://data.arxiuvalencia.eu/vocabulary/c_13b...
# 2         Punt Mobles S.L.  https://data.arxiuvalencia.eu/vocabulary/c_13b...
# 3         Punt Mobles S.L.  https://data.arxiuvalencia.eu/vocabulary/c_13b...
# 4         Punt Mobles S.L.  https://data.arxiuvalencia.eu/vocabulary/c_13b...
#
# ...

# %%
lista_infos = []
for i in range(0,len(datos_csv)):
    idP = datos_csv.iloc[i,0]
    nameP = datos_csv.iloc[i,1]
    nameType = datos_csv.iloc[i,2]
    uriAutor = datos_csv.iloc[i,3]
    nameAutor = datos_csv.iloc[i,4]
    uriMat = datos_csv.iloc[i,5]
    nameMat = datos_csv.iloc[i,6]
    uriTec = datos_csv.iloc[i,7]
    nameTec = datos_csv.iloc[i,8]
    noteP = datos_csv.iloc[i,9]

# %%
# Out:
# 0                      Silla
# 1                 Estantería
# 2                 Estantería
# 3                       Mesa
# 4                       Mesa
#                 ...
# 1822       Boceto industrial
# 1823    Conjunto de juguetes
# 1824    Conjunto de juguetes
# 1825    Conjunto de juguetes
# 1826    Conjunto de juguetes
# Name: nameType, Length: 1827, dtype: object

# %%
datos_csv["combined"] = (
    "Tipología es" + datos_csv.nameType.str.strip()
)

# %%
datos_csv.head()
# Out:
#      idP   nameP    nameType                                        uriAutor  \
# 0   1030  Nº 311       Silla  http://data.arxiuvalencia.eu/organization/3510
# 1  10649   Magic  Estantería  http://data.arxiuvalencia.eu/organization/3307
# 2  10649   Magic  Estantería  http://data.arxiuvalencia.eu/organization/3307
# 3  10649   Magic        Mesa  http://data.arxiuvalencia.eu/organization/3307
# 4  10649   Magic        Mesa  http://data.arxiuvalencia.eu/organization/3307
#
#                  nameAutor                                             uriMat  \
# 0  Vicente García Miralles  https://data.arxiuvalencia.eu/vocabulary/c_13b...
# 1         Punt Mobles S.L.  https://data.arxiuvalencia.eu/vocabulary/c_13b...
# 2         Punt Mobles S.L.  https://data.arxiuvalencia.eu/vocabulary/c_13b...
# 3         Punt Mobles S.L.  https://data.arxiuvalencia.eu/vocabulary/c_13b...
# 4         Punt Mobles S.L.  https://data.arxiuvalencia.eu/vocabulary/c_13b...
#
# ...
